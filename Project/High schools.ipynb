# %%
import os
import pandas as pd
import requests

# %% [markdown]
# ## Antagningen

# %%
# Read in data

# Define the range of years and corresponding URLs
data_info = {
    2020: "https://gymnasieantagningen.storsthlm.se/media/yiobheds/slutantagningsresultat-2020.xlsx",
    2021: "https://gymnasieantagningen.storsthlm.se/media/pvob5j1l/slutantagningsresultat-2021.xlsx",
    2022: "https://gymnasieantagningen.storsthlm.se/media/xhvap2io/slutantagning-2022.xlsx",
    2023: "https://gymnasieantagningen.storsthlm.se/media/zksfvysz/slutantagningsresultat-2023.xlsx",
    2024: "https://gymnasieantagningen.storsthlm.se/media/opnfe50w/slutantagningsresultat-2024.xlsx",
}

download_dir = "antagningsstatistik"  # Directory to store downloaded files

# Ensure the download directory exists
os.makedirs(download_dir, exist_ok=True)

# Download and read Excel files
dataframes = []  # List to store DataFrames for each year
for year, download_url in data_info.items():
    file_name = f"{download_dir}/Slutantagningsresultat_{year}.xlsx"

    # Check if the file already exists
    if not os.path.exists(file_name):
        try:
            # Download the file
            response = requests.get(download_url)
            response.raise_for_status()  # Ensure the request was successful
            with open(file_name, "wb") as file:
                file.write(response.content)
            print(f"Downloaded: {file_name}")
        except requests.exceptions.RequestException as e:
            print(f"Failed to download {file_name}: {e}")
            continue  # Skip this year if download fails
    else:
        print(f"File already exists: {file_name}")

    # Read the Excel file
    try:
        df = pd.read_excel(file_name)
        df["Year"] = year  # Add a column for the year
        dataframes.append(df)
    except Exception as e:
        print(f"Failed to read {file_name}: {e}")

# Combine data from all years
if dataframes:
    df_antagning = pd.concat(dataframes, ignore_index=True)
    print("Final DataFrame:")
    print(df_antagning.head())  # Display the first few rows

    # Save combined data to a CSV file
    output_file = f"{download_dir}/combined_antagningsstatistik.csv"
    df_antagning.to_csv(output_file, index=False)
    print(f"Combined data saved to {output_file}")
else:
    print("No data downloaded.")
    df_antagning = pd.DataFrame()  # Create an empty DataFrame to avoid errors
# Out:
# File already exists: antagningsstatistik/Slutantagningsresultat_2020.xlsx
# File already exists: antagningsstatistik/Slutantagningsresultat_2021.xlsx
# File already exists: antagningsstatistik/Slutantagningsresultat_2022.xlsx
# File already exists: antagningsstatistik/Slutantagningsresultat_2023.xlsx
# File already exists: antagningsstatistik/Slutantagningsresultat_2024.xlsx
# Final DataFrame:
#        År    Kommun                  Skola Organistionsform StudieVagKod  \
# 0  2020.0  Botkyrka  S:t Botvids Gymnasium                K           EK
# 1  2020.0  Botkyrka  S:t Botvids Gymnasium                K        EKEKO
# 2  2020.0  Botkyrka  S:t Botvids Gymnasium                K        EKJUR
# 3  2020.0  Botkyrka  S:t Botvids Gymnasium                K      ESCIRVS
# 4  2020.0  Botkyrka  S:t Botvids Gymnasium                K        HAHAN
#
#                                            Studievag Antagningsgrans Median  \
# 0                               Ekonomiprogrammet EK             0.0  217.5
# 1                               Ekonomiprogrammet EK             0.0  217.5
# 2                               Ekonomiprogrammet EK             0.0  217.5
# 3  Estetiska programmet ES - Särskild variant, ci...             0.0  275.0
# 4  Handels- och administrationsprogrammet HA - Ha...             0.0  142.5
#
#   AntalPlatser AntalAntagna AntalReserver AntalLedigaPlatser  Year  Årtal  \
# 0           30           26             0                  4  2020    NaN
# 1           30           26             0                  4  2020    NaN
# 2           30           26             0                  4  2020    NaN
# 3           20           10             0                 10  2020    NaN
# 4           30           14             0                 16  2020    NaN
#
#    Unnamed: 12
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# Combined data saved to antagningsstatistik/combined_antagningsstatistik.csv

# %%
## Take a part of the original data

# Define parameters
years = range(2020, 2025)  # Range of years to include in the filter
kommuner = [  # List of municipalities to include in the filter
    "Botkyrka", "Danderyd", "Haninge", "Huddinge", "Järfälla", "Lidingö", "Nacka", "Sollentuna", "Solna", 
    "Stockholm", "Sundbyberg", "Södertälje", "Tyresö", "Täby", "Upplands Väsby", "Vallentuna", "Vaxholm", "Värmdö"
]
program_keyword = "Naturvetenskapsprogrammet"  # Keyword to filter specific programs

# Function to filter rows based on criteria
def filter_data(df_antagning, years, kommuner, program_keyword):
    # Filter rows where the year is in the specified range
    df_antagning = df_antagning[df_antagning["Year"].isin(years)]

    # Filter rows where the municipality is in the specified list
    df_antagning = df_antagning[df_antagning["Kommun"].isin(kommuner)]

    # Filter rows where the Studievag column contains the specified keyword
    df_antagning = df_antagning[df_antagning["Studievag"].str.contains(program_keyword, na=False)]

    # Exclude rows where Studievag contains specific keywords (strict matching)
    excluded_keywords = ["estetiska"]
    pattern = r'\b(?:' + '|'.join(excluded_keywords) + r')\b'  # Match whole words only
    df_antagning = df_antagning[~df_antagning["Studievag"].str.contains(pattern, case=False, na=False)]

    # Drop unwanted columns
    columns_to_drop = ["\u00c5r", "Organistionsform", "StudieVagKod", "\u00c5rtal", "Unnamed: 12"]
    df_antagning = df_antagning.drop(columns=[col for col in columns_to_drop if col in df_antagning.columns], errors='ignore')

    return df_antagning

# Apply the filter function
filtered_df_antagning = filter_data(df_antagning, years, kommuner, program_keyword)

# Print the filtered results
print(filtered_df_antagning.head())
# Out:
#       Kommun                  Skola  \
# 7   Botkyrka  S:t Botvids Gymnasium
# 8   Botkyrka  S:t Botvids Gymnasium
# 9   Botkyrka  S:t Botvids Gymnasium
# 19  Botkyrka   Södertörns Gymnasium
# 20  Botkyrka   Södertörns Gymnasium
#
#                                                      Studievag  \
# 7                                 Naturvetenskapsprogrammet NA
# 8                                 Naturvetenskapsprogrammet NA
# 9                                 Naturvetenskapsprogrammet NA
# 19               Naturvetenskapsprogrammet NA - Naturvetenskap
# 20  Naturvetenskapsprogrammet NA - Naturvetenskap och samhälle
#
#    Antagningsgrans Median AntalPlatser AntalAntagna AntalReserver  \
# 7              0.0  210.0           28           11             0
# 8              0.0  210.0           28           11             0
# 9              0.0  210.0           28           11             0
# 19             0.0  275.0           24            8             0
# 20             0.0  227.5           24            2             0
#
#    AntalLedigaPlatser  Year
# 7                  17  2020
# 8                  17  2020
# 9                  17  2020
# 19                 16  2020
# 20                 22  2020

# %%
# Calculate the 5-year median and antagningsgrans averages for each school, program, and municipality
if not filtered_df_antagning.empty:
    # Ensure Median and Antagningsgrans columns are numeric
    filtered_df_antagning["Median"] = pd.to_numeric(filtered_df_antagning["Median"], errors='coerce')
    filtered_df_antagning["Antagningsgrans"] = pd.to_numeric(filtered_df_antagning["Antagningsgrans"], errors='coerce')

    # Calculate the averages
    median_avg_df = (
        filtered_df_antagning.groupby(["Kommun", "Studievag", "Skola"])
        .agg({"Median": "mean", "Antagningsgrans": "mean"})  # Automatically ignores NaN values
        .reset_index()
    )

    # Filter out rows where the 5-year median average is below 250
    median_avg_df = median_avg_df[median_avg_df["Median"] >= 250]

    # 排序结果按 Kommun, Studievag, Skola
    median_avg_df = median_avg_df.sort_values(by=["Median"], ascending=[False])

    # Print the 5-year averages
    pd.set_option("display.max_colwidth", None)  # Ensure full display of Studievag content
    
    print("5-Year Averages by School, Program, and Municipality:")
    print(median_avg_df.head(50))
else:
    print("Filtered dataset is empty.")
# Out:
# 5-Year Averages by School, Program, and Municipality:
#          Kommun  \
# 14     Danderyd
# 88    Stockholm
# 95    Stockholm
# 132   Stockholm
# 163        Täby
# 108   Stockholm
# 104   Stockholm
# 154   Stockholm
# 41        Nacka
# 131   Stockholm
# 109   Stockholm
# 61    Stockholm
# 96    Stockholm
# 138   Stockholm
# 62    Stockholm
# 122   Stockholm
# 70    Stockholm
# 133   Stockholm
# 19     Huddinge
# 142   Stockholm
# 66    Stockholm
# 110   Stockholm
# 22     Huddinge
# 137   Stockholm
# 103   Stockholm
# 63    Stockholm
# 99    Stockholm
# 68    Stockholm
# 97    Stockholm
# 42   Sollentuna
# 162        Täby
# 118   Stockholm
# 169      Värmdö
# 20     Huddinge
# 74    Stockholm
# 5      Botkyrka
# 8      Danderyd
# 111   Stockholm
# 37        Nacka
# 50        Solna
# 171      Värmdö
# 174      Värmdö
# 80    Stockholm
# 117   Stockholm
# 120   Stockholm
# 32        Nacka
# 10     Danderyd
# 4      Botkyrka
# 100   Stockholm
# 136   Stockholm
#
#                                                                         Studievag  \
# 14   Naturvetenskapsprogrammet NA - Särskild variant, matematik (spetsutbildning)
# 88                                  Naturvetenskapsprogrammet NA - Naturvetenskap
# 95                                  Naturvetenskapsprogrammet NA - Naturvetenskap
# 132             Naturvetenskapsprogrammet NA - Naturvetenskap, Entreprenör-Miljö
# 163                                                  Naturvetenskapsprogrammet NA
# 108                                 Naturvetenskapsprogrammet NA - Naturvetenskap
# 104                                 Naturvetenskapsprogrammet NA - Naturvetenskap
# 154             Naturvetenskapsprogrammet NA - Naturvetenskap, Träningslära Dans
# 41                         Naturvetenskapsprogrammet NA - Naturvetenskap, Utland
# 131        Naturvetenskapsprogrammet NA - Naturvetenskap, Entreprenör-Innovation
# 109                                 Naturvetenskapsprogrammet NA - Naturvetenskap
# 61                         Naturvetenskapsprogrammet NA - Natural Science Program
# 96                                  Naturvetenskapsprogrammet NA - Naturvetenskap
# 138                     Naturvetenskapsprogrammet NA - Naturvetenskap, Matematik
# 62              Naturvetenskapsprogrammet NA - Natural Science Program, Engelska
# 122                    Naturvetenskapsprogrammet NA - Naturvetenskap och samhälle
# 70                                  Naturvetenskapsprogrammet NA - Naturvetenskap
# 133                     Naturvetenskapsprogrammet NA - Naturvetenskap, Forskning
# 19                                  Naturvetenskapsprogrammet NA - Naturvetenskap
# 142                         Naturvetenskapsprogrammet NA - Naturvetenskap, Miljö
# 66                                  Naturvetenskapsprogrammet NA - Naturvetenskap
# 110                                 Naturvetenskapsprogrammet NA - Naturvetenskap
# 22                          Naturvetenskapsprogrammet NA - Naturvetenskap, Musik
# 137                  Naturvetenskapsprogrammet NA - Naturvetenskap, Life Science
# 103                                 Naturvetenskapsprogrammet NA - Naturvetenskap
# 63                                  Naturvetenskapsprogrammet NA - Naturvetenskap
# 99                                  Naturvetenskapsprogrammet NA - Naturvetenskap
# 68                                  Naturvetenskapsprogrammet NA - Naturvetenskap
# 97                                  Naturvetenskapsprogrammet NA - Naturvetenskap
# 42                                                   Naturvetenskapsprogrammet NA
# 162                                                  Naturvetenskapsprogrammet NA
# 118                    Naturvetenskapsprogrammet NA - Naturvetenskap och samhälle
# 169                                 Naturvetenskapsprogrammet NA - Naturvetenskap
# 20                     Naturvetenskapsprogrammet NA - Naturvetenskap och samhälle
# 74                                  Naturvetenskapsprogrammet NA - Naturvetenskap
# 5                                   Naturvetenskapsprogrammet NA - Naturvetenskap
# 8                                                    Naturvetenskapsprogrammet NA
# 111                    Naturvetenskapsprogrammet NA - Naturvetenskap och samhälle
# 37                                  Naturvetenskapsprogrammet NA - Naturvetenskap
# 50                                  Naturvetenskapsprogrammet NA - Naturvetenskap
# 171           Naturvetenskapsprogrammet NA - Naturvetenskap och samhälle, Global
# 174   Naturvetenskapsprogrammet NA - Naturvetenskap, Idrott, hälsa och ledarskap
# 80                                  Naturvetenskapsprogrammet NA - Naturvetenskap
# 117                    Naturvetenskapsprogrammet NA - Naturvetenskap och samhälle
# 120                    Naturvetenskapsprogrammet NA - Naturvetenskap och samhälle
# 32                                                   Naturvetenskapsprogrammet NA
# 10                                  Naturvetenskapsprogrammet NA - Naturvetenskap
# 4                                   Naturvetenskapsprogrammet NA - Naturvetenskap
# 100                                 Naturvetenskapsprogrammet NA - Naturvetenskap
# 136            Naturvetenskapsprogrammet NA - Naturvetenskap, Hållbar utveckling
#
#                                                 Skola      Median  \
# 14                                Danderyds gymnasium  851.000000
# 88   Kungsholmens gymnasium/Stockholms musikgymnasium  336.500000
# 95                              Norra Reals gymnasium  335.000000
# 132                             Östra Reals gymnasium  335.000000
# 163                           Täby Enskilda Gymnasium  334.642857
# 108   Viktor Rydberg Gy Campus(fd Jarlaplan/Odenplan)  333.750000
# 104                            Södra Latins gymnasium  333.500000
# 154                              Fryshusets gymnasium  332.500000
# 41                                    Nacka gymnasium  332.000000
# 131                             Östra Reals gymnasium  331.875000
# 109                 Viktor Rydberg Gymnasium Odenplan  330.833333
# 61   Kungsholmens gymnasium/Stockholms musikgymnasium  330.000000
# 96                          P A Fogelströms gymnasium  329.500000
# 138                             Norra Reals gymnasium  329.500000
# 62   Kungsholmens gymnasium/Stockholms musikgymnasium  329.375000
# 122                 Viktor Rydberg Gymnasium Odenplan  329.166667
# 70                                 Enskilda Gymnasiet  327.500000
# 133                             Norra Reals gymnasium  327.000000
# 19                                    Östra gymnasiet  326.500000
# 142                             Norra Reals gymnasium  326.000000
# 66                              Blackebergs gymnasium  323.500000
# 110                             Östra Reals gymnasium  323.000000
# 22                                    Östra gymnasiet  322.500000
# 137                          Anna Whitlocks gymnasium  322.500000
# 103                       Stockholms Idrottsgymnasium  322.500000
# 63                           Anna Whitlocks gymnasium  321.500000
# 99                        Sjölins Gymnasium Södermalm  321.000000
# 68                           Campus Manilla Gymnasium  321.000000
# 97             ProCivitas Privata Gymnasium Stockholm  320.833333
# 42                                            Rudbeck  318.214286
# 162                      Tibble gymnasium campus Täby  318.000000
# 118                       Sjölins Gymnasium Södermalm  317.500000
# 169                                  Värmdö gymnasium  316.500000
# 20                                    Östra gymnasiet  315.500000
# 74                 International IT College of Sweden  315.000000
# 5                                     Tumba Gymnasium  314.500000
# 8                 Viktor Rydberg Gymnasium, Djursholm  314.375000
# 111                             Blackebergs gymnasium  314.000000
# 37                                    Nacka gymnasium  314.000000
# 50                                    Solna Gymnasium  313.500000
# 171                                  Värmdö gymnasium  313.000000
# 174                                  Värmdö gymnasium  311.500000
# 80                             JENSEN gymnasium Södra  310.000000
# 117            ProCivitas Privata Gymnasium Stockholm  310.000000
# 120                       Stockholms Idrottsgymnasium  310.000000
# 32                            Sjölins Gymnasium Nacka  309.285714
# 10                Viktor Rydberg Gymnasium, Djursholm  307.500000
# 4                                  Tullinge Gymnasium  307.500000
# 100      Sjölins Gymnasium Vasastan (fd. Kungsholmen)  306.500000
# 136                                 Globala gymnasiet  306.500000
#
#      Antagningsgrans
# 14        225.000000
# 88        329.000000
# 95        326.000000
# 132       327.500000
# 163       325.714286
# 108       326.250000
# 104       324.000000
# 154       332.500000
# 41        315.500000
# 131       320.625000
# 109       319.166667
# 61        317.500000
# 96        317.500000
# 138       321.500000
# 62        315.000000
# 122       311.666667
# 70        308.500000
# 133       320.000000
# 19        313.500000
# 142       315.500000
# 66        303.000000
# 110       313.000000
# 22        312.500000
# 137       306.500000
# 103       299.000000
# 63        309.500000
# 99        306.000000
# 68        303.500000
# 97        306.666667
# 42        292.857143
# 162       297.500000
# 118       308.500000
# 169       299.500000
# 20        305.000000
# 74        298.750000
# 5         294.500000
# 8         287.500000
# 111       293.500000
# 37        292.500000
# 50        291.000000
# 171       292.500000
# 174       291.000000
# 80        301.250000
# 117       299.166667
# 120       298.750000
# 32        291.785714
# 10        192.500000
# 4         277.500000
# 100       296.500000
# 136       280.000000
