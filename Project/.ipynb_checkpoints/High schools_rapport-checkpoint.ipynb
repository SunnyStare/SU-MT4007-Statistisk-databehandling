# %% [markdown]
# # Which high schools should my daughter apply to?

# %% [markdown]
# ## Abstract

# %% [markdown]
# ##### &nbsp;&nbsp;&nbsp;&nbsp;There are a lot of high schools in Sweden and my daughter doesn't know which ones to apply to. Although all high school admission and graduation results can be found online, manual search is too inefficient and may be missed. Here I built a data processing framework that automatically scraped data from the web and helped me filter which high schools I needed to focus on based on the parameters I set. This data processing framework is reusable, you tell me the parameter variables, and I can use it to help you figure out which high schools you need to focus on.

# %% [markdown]
# ## Introduction

# %% [markdown]
# ##### &nbsp;&nbsp;&nbsp;&nbsp; It's time to apply to high school, do you know which high schools you should consider applying to? <br>
# ##### &nbsp;&nbsp;&nbsp;&nbsp; If you have a score of 340, you can of course apply directly to your favorite schools and favorite programs. But what if you don't have one? You'll need to consider which schools and programs your score will meet for admission.  <br>
# ##### &nbsp;&nbsp;&nbsp;&nbsp; While you can manually check the cut-off scores for a particular school, it's inefficient to do so and it's impossible to survey all of them. And if you only look at some of the schools, you always suspect that you have missed the schools that you should have paid attention to. <br>
# ##### &nbsp;&nbsp;&nbsp;&nbsp; That's how I am. So I built this data processing framework. It automatically reads publicly available data from the web, filters the data according to my requirements, analyzes the data, and finally tells me which schools I need to focus on field trips.

# %% [markdown]
# ## Method and Parameters

# %% [markdown]
# ### 1. Data sources:

# %% [markdown]
# ##### &nbsp;&nbsp;&nbsp;&nbsp; All the raw data comes from these two websites: <br>
# #####  https://gymnasieantagningen.storsthlm.seg <br>
# ##### https://www.skolverket.se/skolutveckling: <br>

# %% [markdown]
# ### 2. Parameters

# %% [markdown]
# ##### &nbsp;&nbsp;&nbsp;&nbsp; I'll take my own situation as an example.
# ##### &nbsp;&nbsp;&nbsp;&nbsp; My family lives in Stockholm and only considers high schools in Stockholm. My daughter is going to read Naturvetenskapsprogrammet. Her current score is 310 points, and to be safe, I collect all the schools where the score of average Median in the last five years is greater than 300.
# ##### &nbsp;&nbsp;&nbsp;&nbsp; One more thing, the "Naturvetenskapsprogrammet" should not combine with "estetiska", "samhälle", "Hållbar utveckling", "Idrott", "Musik", "Dans", "Miljö", "Innovation", my daughter is not interested in these directions.
# ##### &nbsp;&nbsp;&nbsp;&nbsp; To sum up, the parameters should be:

# %% [markdown]
# ##### years = list(range(2020, 2025))
# ##### kommuner = ["Botkyrka", "Danderyd", "Haninge", "Huddinge", "Järfälla", "Lidingö", "Nacka",
# ##### &nbsp;&nbsp;&nbsp;&nbsp; "Sollentuna", "Solna", "Stockholm", "Sundbyberg", "Södertälje", "Tyresö", "Täby",
# ##### &nbsp;&nbsp;&nbsp;&nbsp;"Upplands Väsby", "Vallentuna", "Vaxholm", "Värmdö"]
# ##### program_keyword = "Naturvetenskapsprogrammet"
# ##### average of Median >= 300
# ##### excluded_keywords = ["estetiska", "samhälle", "Hållbar utveckling", "Idrott", "Musik", "Dans", "Miljö", "Innovation"]

# %% [markdown]
# ### 3. Method and code

# %%
import High_school_code
antagning = High_school_code.data_processing()
print(antagning[0])
# Out:
# File already exists: antagningsstatistik/Slutantagningsresultat_2020.xlsx
# File already exists: antagningsstatistik/Slutantagningsresultat_2021.xlsx
# File already exists: antagningsstatistik/Slutantagningsresultat_2022.xlsx
# File already exists: antagningsstatistik/Slutantagningsresultat_2023.xlsx
# File already exists: antagningsstatistik/Slutantagningsresultat_2024.xlsx
# Total rows in result_list: 44
# {'Kommun': 'Danderyd', 'Studievag': 'Naturvetenskapsprogrammet NA - Särskild variant, matematik (spetsutbildning)', 'Skola': 'Danderyds gymnasium', 'Median_Avg': 851.0, 'Antagningsgrans_Avg': 225.0, 'Ratio': 0.26439482961222094}

# %% [markdown]
# ##### &nbsp;&nbsp;&nbsp;&nbsp; Here I downloaded and filtered the data by the above qualifications, and I got 44 different school majors, and I showed the data format for one of them.

# %% [markdown]
# ##### &nbsp;&nbsp;&nbsp;&nbsp; Furthermore, the "Genomsnittligt BetygsPoäng", GBP, at the time of high school graduation and the teacher-student ratio in the school are also important indicators for me, so I used a similar approach to download the relevant data of the above-shortlisted schools in the past 5 years for reference.

# %% [markdown]
# ## Data analysis and visualization

# %% [markdown]
# ### 1. Higher grades at admission, higher grades at graduation?

# %% [markdown]
# ##### &nbsp;&nbsp;&nbsp;&nbsp; I want to verify first, is it true that the higher the admission score, the better the graduation grade? So I'm plotting these two values as the horizontal and vertical coordinates respectively:

# %%
from IPython.display import Image
Image("1.png")

# %% [markdown]
# ##### &nbsp;&nbsp;&nbsp;&nbsp; Yes, that's right. We discover from the chart that the median of different schools is positively correlated with GBP. The best high schools with the highest grades generally have higher admission scores.

# %% [markdown]
# ##### From this perspective, the best high schools are:
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Täby Enskilda Gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Campus Manilla Gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Kungsholmens gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Enskilda Gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Viktor Rydberg Gymnasium Odenplan
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Norra Reals gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Södra Latins gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Östra Reals gymnasiumm

# %% [markdown]
# ### 2. Which schools have high affordability?

# %% [markdown]
# ##### &nbsp;&nbsp;&nbsp;&nbsp; My daughter's grades are not high enough for the top schools, so I focus on admission scores. However, a lower admission score does not necessarily mean a better choice.
# ##### &nbsp;&nbsp;&nbsp;&nbsp; Therefore, I define the admission score divided by the median as a quota that represents the school's 'affordability'. The lower this ratio, the more affordable the school.

# %%
Image("2.png")

# %% [markdown]
# ##### From a perspective of "affordability," the high schools under the red line are worth paying attention to. They are:
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Nacka gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Enskilda Gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Blackebergs gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Stockholms Idrottsgymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Rudbeck
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Viktor Rydberg Gymnasium Djursholm

# %% [markdown]
# ### 3. Which schools with relatively high 'affordability' have relatively higher graduation grades?

# %%
Image("3.png")

# %% [markdown]
# ##### The high schools with relatively high 'affordability' that give relatively higher grades at graduation are:
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Campus Manilla Gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Enskilda Gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Norra Reals gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Stockholms Idrottsgymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Viktor Rydberg Gymnasium Djursholm

# %% [markdown]
# ### 4. Which schools with relatively high 'affordability' have a relatively low student-to-teacher ratio?

# %% [markdown]
# ##### Another metric I care about is this: The fewer students each teacher has to take care of at a given school, the more attention an individual student can receive.
# ##### So which schools with high 'affordability' also have a low student-to-teacher ratio?

# %%
Image("4.png")

# %% [markdown]
# ##### The school on the right at the bottom of the picture is what I'm interested in:
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Tumba Gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Enskilda Gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Östra Gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Campus Manilla Gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Åva gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Solna gymnasium
# ##### &nbsp;&nbsp;&nbsp;&nbsp;Rudbeck

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ##### &nbsp;&nbsp;&nbsp;&nbsp; Above, I used four comparison methods to get four lists of schools. Which schools appear more than once? Then I should take a closer look at them.
# ##### &nbsp;&nbsp;&nbsp;&nbsp; Along these lines, I compared the four lists and selected schools that appeared twice or more in the four lists:

# %% [markdown]
# ##### 'Rudbeck',
# ##### 'Enskilda Gymnasium',
# ##### 'Norra Reals gymnasium',
# ##### 'Campus Manilla Gymnasium',
# ##### 'Stockholms Idrottsgymnasium',
# ##### 'Viktor Rydberg Gymnasium Djursholm'.

# %% [markdown]
# ##### These high schools I should apply for times for open house and put in the schedule.
