# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Define parameters
years = range(2020, 2025)
kommuner = [
    "Botkyrka", "Danderyd", "Haninge", "Huddinge", "Järfälla", "Lidingö", "Nacka", "Sollentuna", "Solna", 
    "Stockholm", "Sundbyberg", "Södertälje", "Tyresö", "Täby", "Upplands Väsby", "Vallentuna", "Vaxholm", "Värmdö"
]
program_keyword = "Naturvetenskapsprogrammet"

# %%
# Base URL (update this based on the actual structure of the website)
base_url = "https://gymnasieantagningen.storsthlm.se/slutantagning/"

# Initialize DataFrame
columns = ["Year", "Kommun", "School", "Program", "Specialization", "Antagningsgräns", "Median"]
data = []

# %%
for year in years:
    for kommun in kommuner:
        # Build the URL for the specific year and kommun
        params = {"year": year, "kommun": kommun}
        response = requests.get(base_url, params=params)
        
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, "html.parser")

            # Parse data for schools and programs
            schools = soup.find_all("div", class_="school-info")
            for school in schools:
                school_name = school.find("h3").get_text(strip=True)

                programs = school.find_all("div", class_="program-info")
                for program in programs:
                    program_name = program.find("h4").get_text(strip=True)

                    if program_keyword in program_name:
                        specialization = program.find("p", class_="specialization").get_text(strip=True)
                        antagningsgrans = program.find("span", class_="antagningsgrans").get_text(strip=True) if program.find("span", class_="antagningsgrans") else "N/A"
                        median = program.find("span", class_="median").get_text(strip=True) if program.find("span", class_="median") else "N/A"

                        # Append to data list
                        data.append([year, kommun, school_name, program_name, specialization, antagningsgrans, median])
        else:
            print(f"Failed to retrieve data for year {year} and kommun {kommun}")

# Create DataFrame
df = pd.DataFrame(data, columns=columns)

print(df.head())
# Out:
# <!DOCTYPE html>
#
# <html class="" lang="sv">
# <head>
# <script data-blockingmode="auto" data-cbid="3ac19664-69a6-4ce6-b2ee-ad32bf6d54ba" id="Cookiebot" src="https://consent.cookiebot.com/uc.js" type="text/javascript"></script>
# <!-- Matomo Tag Manager -->
# <script type="text/javascript">
#             var _mtm = window._mtm = window._mtm || [];
#             _mtm.push({ 'mtm.startTime': (new Date().getTime()), 'event': 'mtm.Start' });
#             var d = document, g = d.createElement('script'), s = d.getElementsByTagName('script')[0];
#             g.type = 'text/javascript'; g.async = true; g.src = 'https://matomo.storsthlm.se/js/container_5M7wavD5.js'; s.parentNode.insertBefore(g, s);
#         </script>
# <!-- End Matomo Tag Manager -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="Slutantagning" name="title"/>
# <meta content="Gymnasieantagningen Storsthlm är Stockholms läns gemensamma antagningskansli. Vi sköter antagningen till gymnasiet, driften av Ungdoms- och elevdatabasen och ansvarar också för att informera ungdomar som ska söka till gymnasiet." name="description"/>
# <meta content="Slutantagning" property="og:title">
# <meta content="Gymnasieantagningen Storsthlm är Stockholms läns gemensamma antagningskansli. Vi sköter antagningen till gymnasiet, driften av Ungdoms- och elevdatabasen och ansvarar också för att informera ungdomar som ska söka till gymnasiet." property="og:description">
# <meta content="https://gymnasieantagningen.storsthlm.se/slutantagning" property="og:url"/>
# <meta content="Slutantagning" property="twitter:title">
# <meta content="Gymnasieantagningen Storsthlm är Stockholms läns gemensamma antagningskansli. Vi sköter antagningen till gymnasiet, driften av Ungdoms- och elevdatabasen och ansvarar också för att informera ungdomar som ska söka till gymnasiet." property="twitter:description">
# <meta content="/media/iczhgepe/hero-image-gya.png" property="og:image"/>
# <meta content="/media/iczhgepe/hero-image-gya.png" name="twitter:image"/>
# <link href="https://gymnasieantagningen.storsthlm.se/slutantagning" rel="canonical"/>
# <title>Slutantagning | Gymnasieantagningen</title>
# <script src="/dist/vendor/scripts/popper.min.js"></script>
# <script src="/dist/vendor/scripts/jquery-3.5.1.min.js"></script>
# <script src="/dist/vendor/scripts/bootstrap.min.js"></script>
# <script src="/dist/vendor/scripts/clipboard.min.js"></script>
# <script defer="" src="/dist/vendor/scripts/alpine.min.js"></script>
# <script src="/dist/scripts/gyantagningen/main.min.js"></script>
# <script src="/dist/vendor/scripts/lity.min.js"></script>
# <script src="/dist/vendor/scripts/js.min.cookie.js"></script>
# <script src="/dist/vendor/scripts/select2.min.js"></script>
# <script src="/dist/vendor/scripts/jquery.ba-throttle-debounce.min.js"></script>
# <script src="/dist/vendor/scripts/jQuery.print.min.js"></script>
# <link href="/dist/css/main-gyantagningen.min.css?v=34535434543543" rel="stylesheet"/>
# <link href="/dist/images/gyantagningen/favicon.ico" rel="shortcut icon" type="image/ico"/>
# <link href="/dist/fonts/webfonts/all.min.css" rel="stylesheet">
# <link href="/dist/vendor/css/lity.min.css" rel="stylesheet"/>
# <link href="/dist/vendor/css/select2.min.css" rel="stylesheet"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link as="font" crossorigin="anonymous" href="/dist/fonts/OpenSans-Regular.ttf" rel="preload" type="font/ttf"/>
# <link as="font" crossorigin="anonymous" href="/dist/fonts/OpenSans-Light.ttf" rel="preload" type="font/ttf"/>
# <link as="font" crossorigin="anonymous" href="/dist/fonts/OpenSans-SemiBold.ttf" rel="preload" type="font/ttf"/>
# <link as="font" crossorigin="anonymous" href="/dist/fonts/trade-gothic-bold-condensed-no-20-2.otf" rel="preload" type="font/otf"/>
# <link as="font" crossorigin="anonymous" href="/dist/fonts/trade-gothic-std-condensed.otf" rel="preload" type="font/otf"/>
# <link as="font" crossorigin="anonymous" href="/dist/fonts/Roboto-Regular.ttf" rel="preload" type="font/ttf"/>
# <link as="font" crossorigin="anonymous" href="/dist/fonts/Lato-Medium.ttf" rel="preload" type="font/ttf"/>
# <link as="font" crossorigin="anonymous" href="/dist/fonts/Galaxie-Polaris.otf" rel="preload" type="font/otf"/>
# <link as="font" crossorigin="anonymous" href="/dist/fonts/webfonts/fa-light-300.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="/dist/fonts/webfonts/fa-solid-900.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="/dist/fonts/webfonts/fa-regular-400.woff2" rel="preload" type="font/woff2"/>
# </link></meta></meta></meta></meta></head>
# <body class="">
# <div id="dark-overlay"></div>
# <div id="mobile-holder" x-data="{navOpenId: -1}">
# <nav class="top-menu" id="top-nav">
# <div id="menu-wrapper">
# <a class="skip-link" href="#main-content">Hoppa över till innehåll</a>
# <a class="nav-logo" href="/">
# <img alt="gyantagningen logo" class="logo" src="/dist/images/gyantagningen/logo.png"/>
# </a>
# <ul>
# <li class="main-nav desktop-mode" id="super-nav-trigger__1085">
# <a href="/om-oss/" onclick="event.stopPropagation()">Om oss</a>
# </li>
# <li class="main-nav desktop-mode" id="super-nav-trigger__4118">
# <a href="/kontaktsida/" onclick="event.stopPropagation()">Kontakt</a>
# </li>
# <li class="main-nav desktop-mode" id="super-nav-trigger__1084">
# <a href="/personal/" onclick="event.stopPropagation()">Personal</a>
# <i aria-label="Öppna menyn" class="show-more fas fa-chevron-square-down" onclick="expandMiddleMenu(1084)" role="button" tabindex="0"></i>
# </li>
# <li class="main-nav desktop-mode" id="super-nav-trigger__12194">
# <a href="https://indra.storsthlm.se/" onclick="event.stopPropagation()">Ansökningswebben</a>
# </li>
# <li class="main-nav desktop-mode language-nav" id="super-nav-trigger__4268">
# <div class="dropdown language-dropdown">
# <button aria-expanded="false" aria-haspopup="true" aria-label="Öppna menyn" class="dropdown-toggle" data-toggle="dropdown" id="dropdownMenuButton" type="button">
# <i class="far fa-globe globe"></i>
# <i class="show-more fas fa-chevron-square-down"></i>
# </button>
# <div aria-labelledby="dropdownMenuButton" class="dropdown-menu">
# <a class="dropdown-item" href="/sprak/english/">English</a>
# <a class="dropdown-item" href="/sprak/arabiska/">عربى (Arabiska)</a>
# <a class="dropdown-item" href="/sprak/somaliska-soomaalida/">Soomaalida</a>
# <a class="dropdown-item" href="/sprak/tigrinska/">Tigrinja</a>
# <a class="dropdown-item" href="/sprak/ryska/">Русский (Ryska)</a>
# <a class="dropdown-item" href="/sprak/українська-ukrainska/">Українська (Ukrainska)</a>
# </div>
# </div>
# </li>
# <li class="main-nav li-extra-action">
# <a aria-label="Öppna sökning" href="#" id="open-search">
# <i class="far fa-search search"></i>
# </a>
# </li>
# <li class="">
# <button class="btn-primary" id="static-right-navigation">
# <span class="desktop-hamburger-text">Meny</span>
# <span class="mobile-hamburger-text">Meny</span>
# <i class="fal fa-bars" id="hamburger"></i>
# </button>
# </li>
# </ul>
# </div>
# </nav>
# <div id="search-bar">
# <div class="container-fluid">
# <div class="row">
# <div class="col-lg-12 vertically-alignment">
# <form action="/sokresultat" class="vertically-alignment__content" method="get">
# <i class="far fa-search search-icon"></i>
# <input aria-label="Sök" id="query" name="query" placeholder="Vad letar du efter?" type="text"/>
# <input name="category" type="hidden" value="elev"/>
# <button type="submit">Sök<i class="far fa-arrow-right"></i></button>
# </form>
# </div>
# </div>
# </div>
# </div>
# <nav class="middle-menu box-shadow-down">
# <div class="middle-menu-inner-container">
# <div class="row">
# <div class="col-md-9">
# <div class="row">
# <div class="col-md-4 super-nav super-menu_1084 style=" data-id="1084"><ul> <li class="level-1">
# <div class="">
# <a href="/personal/arbeta-med-antagning/">
# <span>Arbeta med antagning</span>
# <i class="far fa-arrow-right icon-bigarrow-right"></i>
# </a>
# </div>
# </li>
# <li>
# <div class="nav-link-wrapper">
# <a href="/personal/arbeta-med-antagning/ansvar-roller/">
# <i class="fas fa-angle-right icon-arrow-right"></i>
# <span>Ansvar &amp; roller</span>
# </a>
# </div>
# </li>
# <li>
# <div class="nav-link-wrapper">
# <a href="/personal/arbeta-med-antagning/viktiga-datum/">
# <i class="fas fa-angle-right icon-arrow-right"></i>
# <span>Viktiga datum</span>
# </a>
# </div>
# </li>
# </ul></div><div class="col-md-4 super-nav super-menu_1084 style=" data-id="1084"><span class="divider"></span><ul> <li class="level-1">
# <div class="">
# <a href="/personal/ansokan-antagning/">
# <span>Ansökan &amp; antagning</span>
# <i class="far fa-arrow-right icon-bigarrow-right"></i>
# </a>
# </div>
# </li>
# <li>
# <div class="nav-link-wrapper">
# <a href="/personal/ansokan-antagning/elev-betygsregistrering/">
# <i class="fas fa-angle-right icon-arrow-right"></i>
# <span>Elev- &amp; betygsregistrering</span>
# </a>
# </div>
# </li>
# <li>
# <div class="nav-link-wrapper">
# <a href="/personal/ansokan-antagning/beslutshantering/">
# <i class="fas fa-angle-right icon-arrow-right"></i>
# <span>Beslutshantering</span>
# </a>
# </div>
# </li>
# <li>
# <div class="nav-link-wrapper">
# <a href="/personal/ansokan-antagning/antagningsunderlag/">
# <i class="fas fa-angle-right icon-arrow-right"></i>
# <span>Antagningsunderlag</span>
# </a>
# </div>
# </li>
# <li>
# <div class="nav-link-wrapper">
# <a href="/personal/arbeta-med-antagning/hantering-av-fardighetsprov/">
# <i class="fas fa-angle-right icon-arrow-right"></i>
# <span>Hantering av färdighetsprov</span>
# </a>
# </div>
# </li>
# </ul></div><div class="col-md-4 super-nav super-menu_1084 style=" data-id="1084"><span class="divider"></span><ul> <li class="level-1">
# <div class="">
# <a href="/personal/verktyg/">
# <span>Verktyg</span>
# <i class="far fa-arrow-right icon-bigarrow-right"></i>
# </a>
# </div>
# </li>
# <li>
# <div class="nav-link-wrapper">
# <a href="/personal/verktyg/indra/">
# <i class="fas fa-angle-right icon-arrow-right"></i>
# <span>Att arbeta i Indra</span>
# </a>
# </div>
# </li>
# <li>
# <div class="nav-link-wrapper">
# <a href="/indramanual/introduktion/">
# <i class="fas fa-angle-right icon-arrow-right"></i>
# <span>Indramanual</span>
# </a>
# </div>
# </li>
# <li>
# <div class="nav-link-wrapper">
# <a href="/personal/verktyg/indra-analys/">
# <i class="fas fa-angle-right icon-arrow-right"></i>
# <span>Indra Analys</span>
# </a>
# </div>
# </li>
# <li>
# <div class="nav-link-wrapper">
# <a href="/personal/verktyg/oppna-saker-e-post/">
# <i class="fas fa-angle-right icon-arrow-right"></i>
# <span>Öppna säker e-post</span>
# </a>
# </div>
# </li>
# </ul></div>
# </div>
# </div>
# <div class="col-md-3 blue-menu">
# <ul>
# <li>
# <a href="/personal/blanketter/">
#                                             Blanketter <i class="far fa-arrow-right icon-bigarrow-right"></i>
# </a>
# </li>
# <li>
# <a href="/personal/support-kontakt/">
#                                             Support &amp; kontakt <i class="far fa-arrow-right icon-bigarrow-right"></i>
# </a>
# </li>
# <li>
# <a href="/aktuellt/?category=personal">
#                                             Aktuellt <i class="far fa-arrow-right icon-bigarrow-right"></i>
# </a>
# </li>
# <li>
# <a href="/aktuellt/?category=personal&amp;subCategories=Nyhetsbrev">
#                                             Nyhetsbrev <i class="far fa-arrow-right icon-bigarrow-right"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="row login-label-row">
# <div class="col-md-12 login-label">
# <a href="https://admin.indra.storsthlm.se" rel="noopener" target="_blank">
# <span>Gå till Indra</span>
# </a>
# </div>
# </div>
# </div>
# </nav>
# <nav class="right-menu-wrapper">
# <div class="inner-wrapper">
# <div class="static-right-menu box-shadow">
# <div class="nav-mobile">
# <ul>
# <li class="main-right-nav">
# <div class="nav-link-wrapper">
# <a href="#">Inför gymnasievalet</a>
# <span class="expand" tabindex="0">
# <i class="fas fa-chevron-down"></i>
# </span>
# </div>
# <ul>
# <li class="">
# <div class="name nav-link-wrapper">
# <a href="/viktiga-datum/">Viktiga datum</a>
# </div>
# </li>
# <li class="">
# <div class="name nav-link-wrapper">
# <a href="/ansokan-och-antagning/">Ansökan &amp; antagning</a>
# <span aria-label="Öppna undermenyn" class="expand" tabindex="0">
# <i class="fas fa-chevron-down"></i>
# </span>
# </div>
# <ul>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/ansokan-och-antagning/soka-till-gymnasiet/">
#                             Söka till gymnasiet
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/ansokan-och-antagning/behorighet-och-meritvarde/">
#                             Behörighet &amp; meritvärde
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/ansokan-och-antagning/sokande-till-och-fran-annan-kommun/">
#                             Sökande till annan kommun
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/ansokan-och-antagning/inte-folkbokford-i-sverige/">
#                             Inte folkbokförd i Sverige
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/ansokan-och-antagning/sa-fungerar-antagningen/">
#                             Så fungerar antagningen
#                         </a>
# </div>
# </li>
# </ul>
# </li>
# <li class="">
# <div class="name nav-link-wrapper">
# <a href="/gymnasieprogram/">Gymnasieprogram</a>
# <span aria-label="Öppna undermenyn" class="expand" tabindex="0">
# <i class="fas fa-chevron-down"></i>
# </span>
# </div>
# <ul>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/gymnasieprogram/hogskoleforberedande-program/">
#                             Högskoleförberedande program
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/gymnasieprogram/yrkesprogram/">
#                             Yrkesprogram
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/gymnasieprogram/idrottsutbildningar/">
#                             Idrottsutbildningar
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/gymnasieprogram/riksrekryterande-utbildningar/">
#                             Riksrekryterande utbildningar
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/gymnasieprogram/introduktionsprogram/">
#                             Introduktionsprogram
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/gymnasieprogram/fjarde-tekniskt-ar/">
#                             Fjärde tekniskt år
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/gymnasieprogram/riksgymnasiet-for-rorelsehindrade-i-stockholm/">
#                             Riksgymnasiet för rörelsehindrade i Stockholm
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="https://gymnasieantagningen.storsthlm.se/gymnasieprogram/utbildningar-med-specialpedagogisk-verksamhet/">
#                             Specialpedagogisk verksamhet
#                         </a>
# </div>
# </li>
# </ul>
# </li>
# <li class="">
# <div class="name nav-link-wrapper">
# <a href="/anpassad-gymnasieskola/">Anpassad gymnasieskola</a>
# </div>
# </li>
# <li class="">
# <div class="name nav-link-wrapper">
# <a href="/statistik/">Statistik</a>
# <span aria-label="Öppna undermenyn" class="expand is-active" tabindex="0">
# <i class="fas fa-chevron-up"></i>
# </span>
# </div>
# <ul style="display:block">
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/slutantagning/">
#                             Slutantagning
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/preliminar-antagning/">
#                             Preliminär antagning
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/elevenkater/">
#                             Elevenkäter
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/tidigare-slutantagningar/">
#                             Slutantagningar (2015-2019)
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/tidigare-preliminarantagningar/">
#                             Preliminära antagningar (2015-2019)
#                         </a>
# </div>
# </li>
# </ul>
# </li>
# <li class="">
# <div class="name nav-link-wrapper">
# <a href="/faq/">Frågor &amp; svar</a>
# </div>
# </li>
# <li class="">
# <div class="name nav-link-wrapper">
# <a href="/filmer-elevsidan/">Filmer elevsidan</a>
# </div>
# </li>
# </ul>
# </li>
# <li class="top-navigation">
# <div class="name nav-link-wrapper">
# <a href="/om-oss/">Om oss</a>
# </div>
# </li>
# <li class="top-navigation">
# <div class="name nav-link-wrapper">
# <a href="/kontaktsida/">Kontakt</a>
# </div>
# </li>
# <li class="top-navigation">
# <div class="name nav-link-wrapper">
# <a href="/personal/">Personal</a>
# <span aria-label="Öppna undermenyn" class="expand" tabindex="0">
# <i class="fas fa-chevron-down"></i>
# </span>
# </div>
# <ul>
# <li>
# <div class="name nav-link-wrapper">
# <a href="/personal/arbeta-med-antagning/">Arbeta med antagning</a>
# <span aria-label="Öppna undermenyn" class="expand" tabindex="0">
# <i class="fas fa-chevron-down"></i>
# </span>
# </div>
# <ul>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/arbeta-med-antagning/ansvar-roller/">
#                             Ansvar &amp; roller
#                         </a>
# </div>
# </li>
# <li>
# <div class="name nav-link-wrapper">
# <a href="/personal/arbeta-med-antagning/viktiga-datum/">Viktiga datum</a>
# <span aria-label="Öppna undermenyn" class="expand" tabindex="0">
# <i class="fas fa-chevron-down"></i>
# </span>
# </div>
# <ul>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/arbeta-med-antagning/viktiga-datum/simuleringskorningar-infor-preliminar-slutantagningen/">
#                             Simuleringskörningar under preliminärantagningen
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="#">
#                             Simuleringskörningar inför slutliga antagningen
#                         </a>
# </div>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <div class="name nav-link-wrapper">
# <a href="/personal/ansokan-antagning/">Ansökan &amp; antagning</a>
# <span aria-label="Öppna undermenyn" class="expand" tabindex="0">
# <i class="fas fa-chevron-down"></i>
# </span>
# </div>
# <ul>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/ansokan-antagning/elev-betygsregistrering/">
#                             Elev- &amp; betygsregistrering
#                         </a>
# </div>
# </li>
# <li>
# <div class="name nav-link-wrapper">
# <a href="/personal/ansokan-antagning/beslutshantering/">Beslutshantering</a>
# <span aria-label="Öppna undermenyn" class="expand" tabindex="0">
# <i class="fas fa-chevron-down"></i>
# </span>
# </div>
# <ul>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/ansokan-antagning/beslutshantering/nationell-inriktning-utanfor-samverkansomrade/">
#                             Nationell inriktning utanför samverkansområdet
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/ansokan-antagning/beslutshantering/specialpedagogisk-verksamhet/">
#                             Nationella utbildningar med specialpedagogisk verksamhet
#                         </a>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <div class="name nav-link-wrapper">
# <a href="/personal/ansokan-antagning/antagningsunderlag/">Antagningsunderlag</a>
# <span aria-label="Öppna undermenyn" class="expand" tabindex="0">
# <i class="fas fa-chevron-down"></i>
# </span>
# </div>
# <ul>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/ansokan-antagning/antagningsunderlag/dispens-i-engelska/">
#                             Dispens i engelska
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/ansokan-antagning/antagningsunderlag/fri-kvot-utlandska-betyg/">
#                             Fri kvot – utländska betyg
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/ansokan-antagning/antagningsunderlag/fri-kvot-sarskilda-omstandigheter/">
#                             Fri kvot – särskilda omständigheter
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/ansokan-antagning/antagningsunderlag/anpassad-gymnasieskola/">
#                             Gymnasiesärskolan
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/ansokan-antagning/antagningsunderlag/introduktionsprogram/">
#                             Introduktionsprogram
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/ansokan-antagning/antagningsunderlag/mottagande-i-annan-kommun/">
#                             Mottagande i annan kommun
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/ansokan-antagning/antagningsunderlag/sprakintroduktion/">
#                             Språkintroduktion
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="#">
#                             Sent ändringsval
#                         </a>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/arbeta-med-antagning/hantering-av-fardighetsprov/">
#                             Hantering av färdighetsprov
#                         </a>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <div class="name nav-link-wrapper">
# <a href="/personal/verktyg/">Verktyg</a>
# <span aria-label="Öppna undermenyn" class="expand" tabindex="0">
# <i class="fas fa-chevron-down"></i>
# </span>
# </div>
# <ul>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/verktyg/indra/">
#                             Att arbeta i Indra
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/indramanual/introduktion/">
#                             Indramanual
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/verktyg/indra-analys/">
#                             Indra Analys
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/verktyg/oppna-saker-e-post/">
#                             Öppna säker e-post
#                         </a>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/blanketter/">
#                             Blanketter
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/personal/support-kontakt/">
#                             Support &amp; kontakt
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/aktuellt/?category=personal">
#                             Aktuellt
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/aktuellt/?category=personal&amp;subCategories=Nyhetsbrev">
#                             Nyhetsbrev
#                         </a>
# </div>
# </li>
# </ul>
# </li>
# <li class="top-navigation">
# <div class="name nav-link-wrapper">
# <a href="https://indra.storsthlm.se/">Ansökningswebben</a>
# </div>
# </li>
# <li class="top-navigation">
# <div class="name nav-link-wrapper">
# <a href="#">Other languages</a>
# <span aria-label="Öppna undermenyn" class="expand" tabindex="0">
# <i class="fas fa-chevron-down"></i>
# </span>
# </div>
# <ul>
# <li>
# <div class="name nav-link-wrapper">
# <a href="/sprak/english/">English</a>
# <span aria-label="Öppna undermenyn" class="expand" tabindex="0">
# <i class="fas fa-chevron-down"></i>
# </span>
# </div>
# <ul>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/sprak/english/applicants-from-other-countries/">
#                             Applicants from other countries
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/sprak/english/how-to-apply/">
#                             How to apply
#                         </a>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/sprak/arabiska/">
#                             عربى (Arabiska)
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/sprak/somaliska-soomaalida/">
#                             Soomaalida
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/sprak/tigrinska/">
#                             Tigrinja
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/sprak/ryska/">
#                             Русский (Ryska)
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/sprak/українська-ukrainska/">
#                             Українська (Ukrainska)
#                         </a>
# </div>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="nav-desktop">
# <ul>
# <li class="">
# <div class="name nav-link-wrapper">
# <a href="/viktiga-datum/">Viktiga datum</a>
# </div>
# </li>
# <li class="">
# <div class="name nav-link-wrapper">
# <a href="/ansokan-och-antagning/">Ansökan &amp; antagning</a>
# <span aria-label="Öppna undermenyn" class="expand" tabindex="0">
# <i class="fas fa-chevron-down"></i>
# </span>
# </div>
# <ul>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/ansokan-och-antagning/soka-till-gymnasiet/">
#                             Söka till gymnasiet
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/ansokan-och-antagning/behorighet-och-meritvarde/">
#                             Behörighet &amp; meritvärde
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/ansokan-och-antagning/sokande-till-och-fran-annan-kommun/">
#                             Sökande till annan kommun
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/ansokan-och-antagning/inte-folkbokford-i-sverige/">
#                             Inte folkbokförd i Sverige
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/ansokan-och-antagning/sa-fungerar-antagningen/">
#                             Så fungerar antagningen
#                         </a>
# </div>
# </li>
# </ul>
# </li>
# <li class="">
# <div class="name nav-link-wrapper">
# <a href="/gymnasieprogram/">Gymnasieprogram</a>
# <span aria-label="Öppna undermenyn" class="expand" tabindex="0">
# <i class="fas fa-chevron-down"></i>
# </span>
# </div>
# <ul>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/gymnasieprogram/hogskoleforberedande-program/">
#                             Högskoleförberedande program
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/gymnasieprogram/yrkesprogram/">
#                             Yrkesprogram
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/gymnasieprogram/idrottsutbildningar/">
#                             Idrottsutbildningar
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/gymnasieprogram/riksrekryterande-utbildningar/">
#                             Riksrekryterande utbildningar
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/gymnasieprogram/introduktionsprogram/">
#                             Introduktionsprogram
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/gymnasieprogram/fjarde-tekniskt-ar/">
#                             Fjärde tekniskt år
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/gymnasieprogram/riksgymnasiet-for-rorelsehindrade-i-stockholm/">
#                             Riksgymnasiet för rörelsehindrade i Stockholm
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="https://gymnasieantagningen.storsthlm.se/gymnasieprogram/utbildningar-med-specialpedagogisk-verksamhet/">
#                             Specialpedagogisk verksamhet
#                         </a>
# </div>
# </li>
# </ul>
# </li>
# <li class="">
# <div class="name nav-link-wrapper">
# <a href="/anpassad-gymnasieskola/">Anpassad gymnasieskola</a>
# </div>
# </li>
# <li class="">
# <div class="name nav-link-wrapper">
# <a href="/statistik/">Statistik</a>
# <span aria-label="Öppna undermenyn" class="expand is-active" tabindex="0">
# <i class="fas fa-chevron-up"></i>
# </span>
# </div>
# <ul style="display:block">
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/slutantagning/">
#                             Slutantagning
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/preliminar-antagning/">
#                             Preliminär antagning
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/elevenkater/">
#                             Elevenkäter
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/tidigare-slutantagningar/">
#                             Slutantagningar (2015-2019)
#                         </a>
# </div>
# </li>
# <li>
# <div class="link-wrapper">
# <i class="navigate-icon fas fa-angle-right"></i>
# <a href="/tidigare-preliminarantagningar/">
#                             Preliminära antagningar (2015-2019)
#                         </a>
# </div>
# </li>
# </ul>
# </li>
# <li class="">
# <div class="name nav-link-wrapper">
# <a href="/faq/">Frågor &amp; svar</a>
# </div>
# </li>
# <li class="">
# <div class="name nav-link-wrapper">
# <a href="/filmer-elevsidan/">Filmer elevsidan</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="login">
# <h3>Till ansökningswebben</h3>
# <a class="btn-primary loginbtn" href="https://indra.storsthlm.se" rel="noopener" target="_blank">Gå till Indra</a>
# </div>
# </div>
# </div>
# </nav>
# </div>
# <div class="content-wrapper" id="main-content" tabindex="-1">
# <main class="page_finaladmission" dir="ltr" id="main">
# <section class="hero-banner__standard auto bg--student-orange2">
# <span class="mobile-go-back">
# <i class="fas fa-arrow-alt-circle-left"></i><a href="/">Tillbaka</a>
# </span>
# <header class="container-fluid">
# <div class="outer-container">
# <div class="row">
# <div class="col-lg-12 col-md-12 header-grid vertically-alignment auto">
# <div class="header-grid__inner vertically-alignment__content">
# <ul class="breadcrumb-standard">
# <li><a class="parent" href="/">Hem</a> /</li>
# <li>Slutantagning</li>
# </ul>
# <h1>
#                                     Slutantagning
#                                 </h1>
# <div class="row no-gutters">
# <div class="col-lg-7">
# <p>Här kan du söka efter antagningsgränser för slutantagningen i Stockholms län och Håbo kommun från och med 2020. Börja med att välja år. Fyll sedan i vilken kommun där skolan ligger eller välj en specifik skola för att få upp ett resultat. Tänk på att lediga platser avser de som fanns vid slutantagningen.
#
# Antagningsgränsen är det det meritvärde den sist antagna eleven på utbildningen har. Om alla som sökt blir antagna blir det ingen gräns alls, det vill säga 0.
#
#
# </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="container-fluid filter-container">
# <hr/>
# <div class="row">
# <div class="col-lg-3">
# <div class="form-group">
# <label>Välj år *</label>
# <select id="year-dropdown"></select>
# </div>
# </div>
# <div class="col-lg-3">
# <div class="form-group">
# <label>Kommun där skolan ligger</label>
# <select id="municipality-dropdown"></select>
# </div>
# </div>
# <div class="col-lg-3">
# <div class="form-group">
# <label>Skola</label>
# <select id="school-dropdown"></select>
# </div>
# </div>
# <div class="col-lg-3">
# <div class="form-group">
# <label>Ange sökord</label>
# <div class="input-group">
# <input class="form-control" id="search" placeholder="Ange sökord" type="text"/>
# <div class="input-group-append">
# <span class="input-group-text">
# <i class="far fa-search"></i>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="share-tools">
# <div class="container-fluid">
# <div class="row">
# <div class="col-lg-11">
# <span class="tools no-print">
# <input id="link-to-copy" type="text" value="https://gymnasieantagningen.storsthlm.se/slutantagning/"/>
# <i class="fas fa-link" data-placement="top" data-toggle="tooltip" id="copy-link"></i>
# <i class="fas fa-print" id="print-out" title="Skriv ut"></i>
# <a href="mailto:?subject=Slutantagning&amp;body=https://gymnasieantagningen.storsthlm.se/slutantagning/"><i class="fas fa-envelope" title="Dela"></i></a>
# </span>
# </div>
# </div>
# </div>
# </section>
# <section class="final-admission" id="content">
# <div class="container">
# <div class="row">
# <div class="col-lg-11 offset-lg-1 text-left pl--lg-0 no-print">
# <ul class="list-unstyled filter-list disabled">
# <li>
# <a class="active" data-value="" href="#">Visa alla</a>
# </li>
# <li>
# <a data-value="K" href="#">Kommunala gymnasieskolor</a>
# </li>
# <li>
# <a data-value="F" href="#">Fristående gymnasieskolor</a>
# </li>
# <li>
# <a data-value="L" href="#">Regionens gymnasieskolor</a>
# </li>
# </ul>
# <div class="filter-dropdown-container">
# <select id="filter-dropdown">
# <option selected="" value="">Visa alla</option>
# <option value="K">Kommunala gymnasieskolor</option>
# <option value="F">Fristående gymnasieskolor</option>
# <option value="L">Regionens gymnasieskolor</option>
# </select>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-lg-12">
# <div id="results">
# <div class="row">
# <div class="col-lg-10 offset-lg-1 info-message">
# <h2>Här finns ingenting att visa just nu</h2>
# <p>Börja med att välja år och fyll sedan i vilken kommun eller skola du är intresserad av för att få upp resultat här.</p>
# <picture>
# <source media="(min-width: 1281px)" srcset="/media/kkiel5bw/indy-helmet-5000x5000.svg?mode=pad&amp;rnd=133092585624030000"/>
# <source media="(min-width: 1025px)" srcset="/media/kkiel5bw/indy-helmet-5000x5000.svg?mode=pad&amp;rnd=133092585624030000"/>
# <source media="(max-width: 1024px)" srcset="/media/kkiel5bw/indy-helmet-5000x5000.svg?mode=pad&amp;rnd=133092585624030000"/>
# <img alt="Indy Helmet 5000X5000" class="img-fluid" src="/media/kkiel5bw/indy-helmet-5000x5000.svg?mode=pad&amp;rnd=133092585624030000"/>
# </picture>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <script type="text/javascript">
#     $(function () {
#         initDropdowns();
#
#         getAndSetLatestYear();
#
#         $('#search').keyup($.debounce(500, function (e) {
#             loadAdmissions();
#         }));
#
#         $("#year-dropdown, #school-dropdown, #municipality-dropdown").on("change", function () {
#             loadAdmissions();
#         });
#
#         $(".filter-list a").on("click", function (e) {
#             e.preventDefault();
#
#             $(".filter-list a.active").removeClass("active");
#             $(this).addClass("active");
#
#             loadAdmissions();
#         });
#
#         $("#filter-dropdown").on("change", function () {
#             loadAdmissions();
#         });
#     });
#
#     function getDropdownValue(selector) {
#         return $(selector).select2('data')[0] ? $(selector).select2('data')[0].text : null;
#     }
#
#     function initDropdowns() {
#         $('#year-dropdown').select2({
#             minimumResultsForSearch: -1,
#             placeholder: "Välj år",
#             ajax: {
#                 url: '/umbraco/surface/finalAdmission/GetYearDropdownData',
#                 data: function (params) {
#                     var query = {
#                         isPreliminary: false,
#                     }
#                     return query;
#                 },
#                 processResults: function (data) {
#                     var results = [];
#                     $.each(data, function (index, year) {
#                         results.push({
#                             id: index,
#                             text: year
#                         });
#                     });
#
#                     return {
#                         results: results
#                     };
#                 }
#             }
#         });
#
#         $('#municipality-dropdown').select2({
#             minimumResultsForSearch: -1,
#             allowClear: true,
#             placeholder: "Välj kommun",
#             ajax: {
#                 url: '/umbraco/surface/finalAdmission/GetMunicipalityDropdownData',
#                 data: function (params) {
#                     var query = {
#                         isPreliminary: false,
#                         year: getDropdownValue("#year-dropdown")
#                     }
#                     return query;
#                 },
#
#                 processResults: function (data) {
#                     var results = [];
#                     $.each(data, function (index, municipality) {
#                         results.push({
#                             id: municipality,
#                             text: municipality
#                         });
#                     });
#
#                     return {
#                         results: results
#                     };
#                 }
#             }
#         });
#
#         $('#school-dropdown').select2({
#             minimumResultsForSearch: -1,
#             allowClear: true,
#             placeholder: "Välj skola här",
#             ajax: {
#                 url: '/umbraco/surface/finalAdmission/GetSchoolDropdownData',
#                 data: function (params) {
#                     var query = {
#                         isPreliminary: false,
#                         municipality: getDropdownValue("#municipality-dropdown"),
#                         year: getDropdownValue("#year-dropdown")
#                     }
#                     return query;
#                 },
#
#                 processResults: function (data) {
#                     var results = [];
#                     $.each(data, function (index, school) {
#                         results.push({
#                             id: school,
#                             text: school
#                         });
#                     });
#
#                     return {
#                         results: results
#                     };
#                 }
#             }
#         });
#
#         $("#filter-dropdown").select2({
#             disabled: true,
#             minimumResultsForSearch: -1
#         });
#     }
#
#     function loadAdmissions() {
#         var year = getDropdownValue("#year-dropdown");
#         var orgFormDesktop = $(".filter-list a.active").data("value");
#         var orgFormMobile = $("#filter-dropdown").val();
#
#         if (year) {
#             $("#results").html("<div class='w-100 text-center'><img class='loader-img' src='/dist/images/ball-triangle.svg'/></div>")
#             $("#results").load('/umbraco/surface/finalAdmission/GetAdmissionsPartial',
#                 {
#                     isPreliminary: false,
#                     year: year,
#                     municipality: getDropdownValue("#municipality-dropdown"),
#                     school: getDropdownValue("#school-dropdown"),
#                     searchTerm: $("#search").val(),
#                     orgForm: orgFormDesktop === "" ? orgFormMobile : orgFormDesktop
#                 }, function () {
#                     $(".filter-list").removeClass("disabled");
#                     $("#filter-dropdown").prop("disabled", false);
#                 });
#         }
#     }
#
#     function getAndSetLatestYear() {
#         var yearDropdown = $('#year-dropdown');
#         $.ajax({
#             type: 'GET',
#             url: '/umbraco/surface/finalAdmission/getLatestYear',
#             data: {
#                 isPreliminary: false
#             }
#         }).then(function (data) {
#             if (data) {
#                 var option = new Option(data, data, true, true);
#                 yearDropdown.append(option).trigger('change');
#             }
#         });
#     }
# </script>
# <section class="related-links">
# <div class="container-fluid">
# <div class="row">
# <div class="col-lg-12">
# <h3>Du kanske också är intresserad av:</h3>
# </div>
# </div>
# <div class="row">
# <div class="col col-link">
# <div class="link-wrapper">
# <span class="arrow-right-rounded">
# <i class="far fa-arrow-right"></i>
# </span>
# <a class="pufflink" href="/tidigare-slutantagningar/">Slutantagningar (2015-2019)
#                             </a>
# </div>
# </div>
# <div class="col col-link">
# <div class="link-wrapper">
# <span class="arrow-right-rounded">
# <i class="far fa-arrow-right"></i>
# </span>
# <a class="pufflink" href="/statistik/ladda-ned-antagningsstatistik/">Ladda ned antagningsstatistik
#                             </a>
# </div>
# </div>
# <div class="col col-link">
# <div class="link-wrapper">
# <span class="arrow-right-rounded">
# <i class="far fa-arrow-right"></i>
# </span>
# <a class="pufflink" href="/ansokan-och-antagning/behorighet-och-meritvarde/">Behörighet och meritvärde
#                             </a>
# </div>
# </div>
# </div>
# </div>
# </section>
# </main>
# <footer>
# <div class="container">
# <div class="row">
# <div class="col-sm-4 left">
# <img alt="logo" class="logo" src="/dist/images/gyantagningen/logo.png">
# <p class="about">
#                         Gymnasieantagningen Storsthlm har hand om antagningen till de kommunala och fristående gymnasieskolorna samt de anpassade gymnasieskolorna i Stockholms läns kommuner samt Håbo och Gnesta kommun.
#                     </p>
# </img></div>
# <div class="col-sm-4 middle">
# <div class="social-icons">
# </div>
# <ul class="contact">
# <li class="email">
# <i class="fas fa-envelope"></i> <span><a href="mailto:gymnasieantagningen@storsthlm.se">gymnasieantagningen@storsthlm.se</a></span>
# </li>
# </ul>
# </div>
# <div class="col-sm-4 right">
# <div class="hr d-sm-none"></div>
# <div class="row">
# <div class="col-lg-12 col-md-12">
# <ul class="links">
# <li>
# <a href="https://utbildningsguiden.skolverket.se/">
#                         Skolverkets utbildningsguide<i class="fas fa-arrow-alt-circle-right"></i>
# </a>
# </li>
# <li>
# <a href="https://www.studera.nu/">
#                         Universitets- och högskolerådets webbplats<i class="fas fa-arrow-alt-circle-right"></i>
# </a>
# </li>
# <li>
# <a href="https://www.yrkeshogskolan.se/">
#                         Yrkeshögskolans webbplats<i class="fas fa-arrow-alt-circle-right"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <div id="CookieDeclarationChangeConsent" style="display: block">
# <a class="btn-primary" href="javascript:CookieConsent.renew();CookieDeclaration.SetUserStatusLabel();">
# <span>
# <svg fill="none" height="27" viewbox="0 0 28 27" width="28" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M27.746 13.3232L27.7469 13.377C27.7476 13.418 27.7482 13.4589 27.7482 13.5001C27.7482 20.944 21.7334 27.0001 14.34 27.0001C6.94673 27.0001 0.931885 20.944 0.931885 13.5001C0.931885 6.05611 6.94673 0 14.34 0C14.3813 0 14.4224 0.000647498 14.4635 0.00135974L14.5159 0.00220149C14.8552 0.00660448 15.1327 0.27564 15.1499 0.616806C15.1984 1.57944 15.7699 2.42928 16.6412 2.83474C16.8144 2.91536 16.9432 3.06933 16.9925 3.25497C17.042 3.44061 17.0069 3.63874 16.8969 3.79576C16.32 4.61905 16.2701 5.71404 16.7698 6.58544C17.2277 7.38406 18.0824 7.88018 19.0002 7.88018C19.0776 7.88018 19.1558 7.87661 19.2326 7.86956C19.422 7.8524 19.6106 7.92064 19.7456 8.05662C19.8806 8.19246 19.9487 8.38173 19.9314 8.57313C19.8405 9.57649 20.3411 10.5499 21.2066 11.053C21.5975 11.2802 22.0408 11.4002 22.4886 11.4002C23.0172 11.4002 23.5459 11.2315 23.9771 10.9252C24.1331 10.8144 24.3299 10.7792 24.5143 10.8289C24.6986 10.8787 24.8515 11.0084 24.9316 11.1828C25.3344 12.0604 26.1789 12.6359 27.1355 12.6845C27.4745 12.7018 27.7419 12.9814 27.746 13.3232ZM4.01719 8.29516C4.79732 8.29516 5.43199 7.65614 5.43199 6.87066C5.43199 6.44959 5.24948 6.06168 4.94562 5.79601C4.35693 6.52237 3.84973 7.31795 3.4377 8.16863C3.61834 8.25054 3.81493 8.29516 4.01719 8.29516ZM23.7644 19.1366C23.7644 19.6172 24.0081 20.0572 24.3898 20.3172C24.9122 19.539 25.3476 18.6969 25.6825 17.8056C25.5237 17.7445 25.3545 17.7121 25.1792 17.7121C24.3991 17.7121 23.7644 18.3511 23.7644 19.1366ZM8.50123 9.13697C8.50123 7.63743 9.71288 6.41748 11.2022 6.41748C12.6916 6.41748 13.9032 7.63743 13.9032 9.13697C13.9032 10.6365 12.6916 11.8565 11.2022 11.8565C9.71288 11.8565 8.50123 10.6365 8.50123 9.13697ZM9.41676 20.3506C8.63663 20.3506 8.00196 19.7116 8.00196 18.9261C8.00196 18.1406 8.63663 17.5016 9.41676 17.5016C10.1969 17.5016 10.8316 18.1406 10.8316 18.9261C10.8316 19.7116 10.1969 20.3506 9.41676 20.3506ZM14.5952 16.8516C14.5952 18.0655 15.5761 19.0531 16.7817 19.0531C17.9874 19.0531 18.9683 18.0655 18.9683 16.8516C18.9683 15.6377 17.9874 14.6501 16.7817 14.6501C15.5761 14.6501 14.5952 15.6377 14.5952 16.8516Z" fill="white" fill-rule="evenodd"></path>
# </svg>
# </span>
# <span class="text">Visa cookie-information</span>
# </a>
# </div>
# <!-- ImBox -->
# <script type="text/javascript">
#             var _sid = '2194';
#             (function () {
#                 var se = document.createElement('script'); se.type = 'text/javascript'; se.async = true;
#                 se.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'files.imbox.io/app/dist/initWidget.js';
#                 var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(se, s);
#             })();
#         </script> <!-- //ImBox Script -->
# </body>
# </html>
