# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # IRIS data

# %%
# Read in data
df = pd.read_csv("https://raw.githubusercontent.com/su-mt4007/data/refs/heads/main/IRIS.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## Is there a relationship between sepal dimensions and petal dimensions?

# %%
# Two graphs in one row
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

background_color = '#f0f0f0'

# Numerical vs. Numerical - sepal_length vs. petal_length                         
sns.scatterplot(x='sepal_length', y='petal_length', hue='species', data=df, palette='Set1', ax=axes[0]) 
axes[0].set_title('The relationship between Sepal Length and Petal Length') 
axes[0].set_xlabel('Sepal Length') 
axes[0].set_ylabel('Petal Length')
axes[0].set_facecolor(background_color)
axes[0].grid(True, color='white', alpha=0.6)

# Numerical vs. Numerical - sepal_length vs. petal_length                         
sns.scatterplot(x='sepal_width', y='petal_width', hue='species', data=df, palette='Set1', ax=axes[1]) 
axes[1].set_title('The relationship between Sepal Width and Petal Width') 
axes[1].set_xlabel('Sepal Width') 
axes[1].set_ylabel('Petal Width')
axes[1].set_facecolor(background_color)
axes[1].grid(True, color='white', alpha=0.6)

# print
plt.tight_layout() 
plt.show()

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp;There are visually noticeable correlations
# ### between sepal dimensions and petal dimensions
# ### for iris-versicolor and iris-virginica,
# ### but not for iris-setosa.

# %% [markdown]
# ## How are the sepal and petal dimensions distributed?

# %%
# Create figure and subplots
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
background_color = '#f0f0f0'

# Plot the first subplot (Species vs. Sepal Width)
sns.boxplot(x='species', y='sepal_width', data=df, hue='species', palette='Set1', ax=axes[0, 0])
axes[0, 0].set_xlabel('Species')
axes[0, 0].set_ylabel('Sepal Width')
axes[0, 0].set_facecolor(background_color)
axes[0, 0].grid(True, color='white', alpha=0.6)

# Plot the second subplot (Species vs. Sepal length)
sns.boxplot(x='species', y='sepal_length', data=df, hue='species', palette='Set1', ax=axes[0, 1])
axes[0, 1].set_xlabel('Species')
axes[0, 1].set_ylabel('Sepal Length')
axes[0, 1].set_facecolor(background_color)
axes[0, 1].grid(True, color='white', alpha=0.6)

# Plot the third subplot (Species vs. Petal Width)
sns.boxplot(x='species', y='petal_width', data=df, hue='species', palette='Set1', ax=axes[1, 0])
axes[1, 0].set_xlabel('Species')
axes[1, 0].set_ylabel('Petal Width')
axes[1, 0].set_facecolor(background_color)
axes[1, 0].grid(True, color='white', alpha=0.6)

# Plot the fourth subplot (Species vs. Petal length)
sns.boxplot(x='species', y='petal_length', data=df, hue='species', palette='Set1', ax=axes[1, 1])
axes[1, 1].set_xlabel('Species')
axes[1, 1].set_ylabel('Petal Length')
axes[1, 1].set_facecolor(background_color)
axes[1, 1].grid(True, color='white', alpha=0.6)

# Adjust subplot layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp; The petals of Iris-setosa are the smallest among the three species,
# ### and their size and shape are particularly consistent.

# %% [markdown]
# ## How the different variables are related to each other,
# ## &nbsp;&nbsp;&nbsp;&nbsp; the pair-plot of the three types of iris.

# %%
selected_features = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
palette = {'Iris-setosa': 'red', 'Iris-versicolor': 'blue', 'Iris-virginica': 'green'}
sns.pairplot(df[selected_features], hue='species', palette=palette)
plt.show()

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp; The ratio between the length and width of the sepals of Iris-setosa is relatively fixed, meaning that its shape is stable.The ratio between the length and width of the sepals in the other two species varies within a certain size range, meaning that their shape is less stable.
# ### &nbsp;&nbsp;&nbsp;&nbsp; The length and width of the petal of Iris-setosa are relatively fixed, meaning that both its shape and its size are stable. The length and width of the sepals in the other two species varies, but the ratio between them is relatively fixed. That means, the size of the other two species are relatively less stable, Iris-virginica are often bigger than Iris-versicolor, but the shape of petal of these two species are the same.

# %% [markdown]
# # Birdwatching

# %%
# Read in data
df2 = pd.read_csv("https://raw.githubusercontent.com/su-mt4007/data/refs/heads/main/artportalen.csv")
df2.info()
df2.head(50)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21916 entries, 0 to 21915
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      21916 non-null  int64
#  1   Taxonsorteringsordning  21916 non-null  int64
#  2   Rödlistade              4777 non-null   object
#  3   Artnamn                 21916 non-null  object
#  4   Vetenskapligt namn      21916 non-null  object
#  5   Auktor                  21843 non-null  object
#  6   Antal                   21916 non-null  object
#  7   Ålder/stadium           757 non-null    object
#  8   Kön                     2023 non-null   object
#  9   Aktivitet               16745 non-null  object
#  10  Lokalnamn               21916 non-null  object
#  11  Ostkoordinat            21916 non-null  int64
#  12  Nordkoordinat           21916 non-null  int64
#  13  Noggrannhet             21916 non-null  int64
# ...

# %%
df["Nordkoordinat"].unique()
# Out:
# array([6586736, 6585523, 6585860, 6586750, 6583460, 6584322, 6585142,
#        6584462, 6584744, 6589636, 6580970, 6581772, 6581440, 6581548,
#        6580562, 6581052, 6580418, 6580712, 6581570, 6582070, 6581900,
#        6580800, 6580760, 6580640, 6581160, 6580228, 6580005, 6585934,
#        6581280, 6582023, 6580325, 6580200, 6580470, 6580537, 6580130,
#        6580960, 6586035, 6586049, 6584600, 6584820, 6586830, 6586263,
#        6586274, 6581287, 6581430, 6585770, 6586230, 6586660, 6582063,
#        6581370, 6581271, 6583376, 6580340, 6580263, 6581110, 6580326,
#        6580700, 6581533, 6581230, 6581390, 6580934, 6586950, 6583806,
#        6583361, 6586289, 6586020, 6586017, 6586186, 6586889, 6581605,
#        6589556, 6588260, 6589840, 6580167, 6581060, 6580480, 6580852,
#        6582624, 6584813, 6581943, 6585323, 6580820, 6585409, 6587617,
#        6586280, 6588590, 6581180, 6585640, 6584620, 6584921, 6580310,
# ...

# %% [markdown]
# ## What are the most prevelant species?

# %%
df2["Antal"].unique()
# Out:
# array(['2', '1', '10', '5', '6', '3', '7', '30', '8', '4', 'noterad',
#        '100', '16', '222', '60', '18', '50', '12', '25', '20', '21',
#        '600', '51', '80', '250', '200', '15', '11', '70', '71', '35',
#        '3000', '67', '9', '26', '150', '40', '17', '14', '28', '1000',
#        'Ej återfunnen', '13', '63', '22', '120', '138', '1100', '19',
#        '42', '47', '23', '96', '85', '10000', '400', '45', '130', '82',
#        '68', '34', '109', '122', '39', '41', '57', '49', '116', '125',
#        '75', '81', '55', '43', '86', '156', '27', '235', '46', '115',
#        '65', '110', '140', '141', '32', '123', '66', '145', '203', '168',
#        '61', '24', '83', '119', '74', '38', '192', '88', '53', '33', '97',
#        '52', '56', '44', '36', '37', '31', '185', '172', '108', '90',
#        '300', '175', '95', '162', '54', '29', '270', '48', '225', '89',
#        '155', '133', '72', '190', '124', '62', '107', '248', '408', '570'],
#       dtype=object)

# %%
# Select the relevant parts of the data and fix the data type
relevant_df2_1 = df2[["Artnamn", "Antal"]].copy()
relevant_df2_1.loc[relevant_df2_1["Antal"] == "noterad"] = 1 
relevant_df2_1.loc[relevant_df2_1["Antal"] == "Ej återfunnen"] = 0
relevant_df2_1["Antal"] = relevant_df2_1["Antal"].astype('int64')
relevant_df2_1["Antal"].unique()
# Out:
# array([    2,     1,    10,     5,     6,     3,     7,    30,     8,
#            4,   100,    16,   222,    60,    18,    50,    12,    25,
#           20,    21,   600,    51,    80,   250,   200,    15,    11,
#           70,    71,    35,  3000,    67,     9,    26,   150,    40,
#           17,    14,    28,  1000,     0,    13,    63,    22,   120,
#          138,  1100,    19,    42,    47,    23,    96,    85, 10000,
#          400,    45,   130,    82,    68,    34,   109,   122,    39,
#           41,    57,    49,   116,   125,    75,    81,    55,    43,
#           86,   156,    27,   235,    46,   115,    65,   110,   140,
#          141,    32,   123,    66,   145,   203,   168,    61,    24,
#           83,   119,    74,    38,   192,    88,    53,    33,    97,
#           52,    56,    44,    36,    37,    31,   185,   172,   108,
#           90,   300,   175,    95,   162,    54,    29,   270,    48,
# ...

# %%
# Sum and Sort
grouped_df2_1 = relevant_df2_1.groupby ("Artnamn").sum()
sorted_df2_1 = grouped_df2_1.sort_values("Antal", ascending=False)
sorted_df2_1.head(3)
# Out:
#            Antal
# Artnamn
# Grönsiska  20211
# Sothöna     8308
# Gräsand     7167

# %% [markdown]
# ## What is the monthly distribution of the top 3 most prevelant species?

# %%
df2["Slutdatum"].unique()
# Out:
# array(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#        '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#        '2022-01-09', '2022-01-10', '2022-01-11', '2022-01-12',
#        '2022-01-13', '2022-01-14', '2022-01-15', '2022-01-16',
#        '2022-01-17', '2022-01-18', '2022-01-19', '2022-01-20',
#        '2022-01-21', '2022-01-22', '2022-01-23', '2022-01-24',
#        '2022-01-25', '2022-01-26', '2022-01-27', '2022-01-28',
#        '2022-01-29', '2022-01-30', '2022-01-31', '2022-02-01',
#        '2022-02-02', '2022-02-03', '2022-02-04', '2022-02-05',
#        '2022-02-06', '2022-02-07', '2022-02-08', '2022-02-09',
#        '2022-02-10', '2022-02-11', '2022-02-12', '2022-02-13',
#        '2022-02-14', '2022-02-15', '2022-02-16', '2022-02-17',
#        '2022-02-18', '2022-02-19', '2022-02-20', '2022-02-22',
#        '2022-02-23', '2022-02-24', '2022-02-25', '2022-02-26',
#        '2022-02-27', '2022-02-28', '2022-03-01', '2022-03-02',
# ...

# %%
# Select the relevant parts of the data 
relevant_df2_2 = df2[["Artnamn", "Antal","Slutdatum"]].copy()
# Fix the data type
relevant_df2_2["Antal"].loc[relevant_df2_2["Antal"] == "noterad"] = 1
relevant_df2_2["Antal"].loc[relevant_df2_2["Antal"] == "Ej återfunnen"] = 0
relevant_df2_2["Antal"] = relevant_df2_2["Antal"].astype('int64')
# Seperate data in month
relevant_df2_2['Slutdatum'] = pd.to_datetime(relevant_df2_2['Slutdatum'])
relevant_df2_2['Month'] = relevant_df2_2['Slutdatum'].dt.month
relevant_df2_2
# Out:
# C:\Users\User-Dator\AppData\Local\Temp\ipykernel_15264\3224810850.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   relevant_df2_2["Antal"].loc[relevant_df2_2["Antal"] == "noterad"] = 1
# ...

# %%
# Groönsiska
Gronsiska = relevant_df2_2.loc[(relevant_df2_2["Artnamn"]=="Grönsiska")]
sns.histplot(Gronsiska['Month'])
plt.xlabel('Month') 
plt.ylabel('Antal') 
plt.title('Monthly Distribution of Grönsiska') 
plt.show()

# %%
# Sothöna
Sothona = relevant_df2_2.loc[(relevant_df2_2["Artnamn"]=="Sothöna")]
sns.histplot(Sothona['Month'])
plt.xlabel('Month') 
plt.ylabel('Antal') 
plt.title('Monthly Distribution of Sothöna') 
plt.show()

# %%
# Gräsand
Grasand = relevant_df2_2.loc[(relevant_df2_2["Artnamn"]=="Gräsand")]
sns.histplot(Grasand['Month'])
plt.xlabel('Month') 
plt.ylabel('Antal') 
plt.title('Monthly Distribution of Gräsand') 
plt.show()

# %% [markdown]
# ## What are the rarest species?

# %%
# Sum and Sort
grouped_df2_3 = relevant_df2_1.groupby ("Artnamn").sum()
Rarest = grouped_df2_3.loc[(grouped_df2_3["Antal"]==1)]
Rarest
# Out:
#                            Antal
# Artnamn
# Bivråk                         1
# Bändelkorsnäbb                 1
# Ejder                          1
# Fjällvråk                      1
# Forsärla                       1
# Gravand                        1
# Lappsparv                      1
# Ormvråk, underarten buteo      1
# Rosenfink                      1
# Röd glada                      1
# Rödbena                        1
# Spillkråka                     1
# Storlom                        1
# Strömstare                     1
# Tornfalk                       1
# Trädlärka                      1
# Varfågel                       1
# Vinterhämpling                 1
# Ägretthäger                    1

# %% [markdown]
# ## Where are the rarest species? Perhaps we could allocate more resources to these areas to protect these birds.

# %% [markdown]
# ### Therefore, let me count which kommun has the most "rarest" bird species.

# %%
# Select the relevant parts of the data and fix the data type
relevant_df2_4 = df2[["Artnamn", "Antal","Kommun"]].copy()
relevant_df2_4["Antal"].loc[relevant_df2_4["Antal"] == "noterad"] = 1
relevant_df2_4["Antal"].loc[relevant_df2_4["Antal"] == "Ej återfunnen"] = 0
relevant_df2_4["Antal"] = relevant_df2_4["Antal"].astype('int64')
relevant_df2_4["Kommun"].unique()
# Out:
# C:\Users\User-Dator\AppData\Local\Temp\ipykernel_15264\3189970529.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   relevant_df2_4["Antal"].loc[relevant_df2_4["Antal"] == "noterad"] = 1
# ...

# %%
grouped_df2_4 = relevant_df2_4.groupby ("Artnamn").sum()
Rarest = grouped_df2_4.loc[(grouped_df2_4["Antal"]==1)]
Rarest
# Out:
#                            Antal      Kommun
# Artnamn
# Bivråk                         1   Stockholm
# Bändelkorsnäbb                 1   Stockholm
# Ejder                          1   Stockholm
# Fjällvråk                      1       Solna
# Forsärla                       1   Stockholm
# Gravand                        1   Stockholm
# Lappsparv                      1   Stockholm
# Ob. korsnäbb                   1   Stockholm
# Ormvråk, underarten buteo      1   Stockholm
# Rosenfink                      1   Stockholm
# Röd glada                      1   Stockholm
# Rödbena                        1   Stockholm
# Spillkråka                     1       Solna
# Storlom                        1   Stockholm
# Strömstare                     1  Sollentuna
# Tornfalk                       1   Stockholm
# Trädlärka                      1   Stockholm
# Varfågel                       1       Solna
# Vinterhämpling                 1   Stockholm
# Ägretthäger                    1   Stockholm

# %%
Kommun_Rarest = Rarest.groupby ("Kommun").sum()
# Calculate the percentage 
total_counts = Kommun_Rarest["Antal"].sum() 
Kommun_Rarest["Percentage"] = (Kommun_Rarest["Antal"] / total_counts) * 100

Kommun_Rarest.sort_values("Antal", ascending=False)
# Out:
#             Antal  Percentage
# Kommun
# Stockholm      16        80.0
# Solna           3        15.0
# Sollentuna      1         5.0

# %% [markdown]
# ### Statistics show that Stockholm has the most rarest bird species.

# %% [markdown]
# ## But, maybe, some species of birds are not rare, but are just less common in Stockholm?

# %% [markdown]
# ### Therefore, let me count which kommun has the most birds of the species on the "red list".

# %%
# Select the relevant parts of the data and fix the data type
relevant_df2_5 = df2[["Artnamn", "Antal","Kommun","Rödlistade"]].copy()
relevant_df2_5["Antal"].loc[relevant_df2_5["Antal"] == "noterad"] = 1
relevant_df2_5["Antal"].loc[relevant_df2_5["Antal"] == "Ej återfunnen"] = 0
relevant_df2_5["Antal"] = relevant_df2_5["Antal"].astype('int64')
relevant_df2_5["Rödlistade"].unique()
# Out:
# C:\Users\User-Dator\AppData\Local\Temp\ipykernel_15264\55478118.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   relevant_df2_5["Antal"].loc[relevant_df2_5["Antal"] == "noterad"] = 1
# ...

# %%
# Select all the threatened species, 
# i.e. those endangered(EN) and vulnerable(VU) in the column "Rödlistade".
Rare = relevant_df2_5.loc[(relevant_df2_5["Rödlistade"]=='EN') | (relevant_df2_5["Rödlistade"]=='VU')]
Rare
# Out:
#            Artnamn  Antal      Kommun Rödlistade
# 14         Gråtrut      1       Solna         VU
# 33        Grönfink      5       Solna         EN
# 51         Gråtrut     30   Stockholm         VU
# 104        Gråtrut      7   Stockholm         VU
# 105       Havstrut      1   Stockholm         VU
# ...            ...    ...         ...        ...
# 21843        Stare      1       Solna         VU
# 21853     Grönfink      1       Solna         EN
# 21866  Tornseglare      3  Sollentuna         EN
# 21896     Grönfink      1  Sollentuna         EN
# 21910     Grönfink      4   Stockholm         EN
#
# [1843 rows x 4 columns]

# %%
Antal_Kommun_Rare = Rare[["Antal","Kommun"]].copy()
Kommun_Antal_Rare = Antal_Kommun_Rare.groupby ("Kommun").sum()
# Calculate the percentage column 
total_count = Kommun_Antal_Rare["Antal"].sum() 
Kommun_Antal_Rare["Percentage"] = (Kommun_Antal_Rare["Antal"] / total_count) * 100

Kommun_Antal_Rare.sort_values("Antal", ascending=False)
# Out:
#             Antal  Percentage
# Kommun
# Stockholm    5253   76.809475
# Solna         858   12.545694
# Lidingö       498    7.281766
# Sollentuna    230    3.363065

# %% [markdown]
# ### Statistics show again that Stockholm has the most birds of the species on the "red list".

# %% [markdown]
# ## One more time, but, maybe, it is only because there are more observations in Stockholm?

# %% [markdown]
# ### The I need to count how many observations each kommun has in the data table.

# %%
# Count the number of rows for each unique value
Observation_Kommun = df2["Kommun"].value_counts().reset_index() 
# Rename columns 
Observation_Kommun.columns = ["Kommun", "Counts"] 
# Calculate the percentage 
total_counts = Observation_Kommun["Counts"].sum() 
Observation_Kommun["Percentage"] = (Observation_Kommun["Counts"] / total_counts) * 100
# Print the resulting dataframe 
Observation_Kommun
# Out:
#        Kommun  Counts  Percentage
# 0   Stockholm   15436   70.432561
# 1       Solna    4031   18.392955
# 2  Sollentuna    2292   10.458113
# 3     Lidingö     157    0.716372

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp; Oh! No! It appears that the majority of rare bird species recorded in the data are from Stockholm, primarily because most of the observation records come from Stockholm. Therefore, this data source is not ideal for studying where to invest resources to protect rare birds. Next time, it would be better to mobilize observers outside of Stockholm to be more diligent in their observations.

# %% [markdown]
# # Predicting Strokes

# %%
# Read in data
df3 = pd.read_csv("https://raw.githubusercontent.com/su-mt4007/data/refs/heads/main/stroke-data.csv")
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %% [markdown]
# ## Is stroke-data.csv a good data source？

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp; I got hurt in my exploration of birdwatching, so I think I should first explore if stroke-data.csvis a good data source.

# %%
sns.histplot(df3['age'])
plt.title('Distribution of Age')
plt.show()

# %% [markdown]
# ### Ok, the distribution of age is not perfect, but acceptable, I think.

# %%
sns.histplot(df3['gender'])
plt.title('Distribution of Gender')
plt.show()

# %% [markdown]
# ### The distribution of gender is good, I think.

# %%
sns.histplot(df3['hypertension'])
plt.title('Distribution of Hypertension')
plt.show()

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp; No, the 'hypertension' should be continuous, not just yes or no. I suspect that the more severe the hypertension, the higher the likelihood of a stroke, but this cannot be verified from this data source.

# %% [markdown]
# ## But maybe I can still search some relationships among them?

# %%
sns.boxplot(data=df3, x='stroke', y='age', hue='stroke', palette=["#3498db", "#e74c3c"])
plt.title("Age Distribution by Stroke Status")
plt.show()

# %% [markdown]
# ### It is clear that the risk of stroke is higher in the old people.

# %%
#Group data to get the proportional distribution of stroke status for those with heart disease 
stroke_counts = df3.groupby('heart_disease')['stroke'].value_counts(normalize=True).unstack()
stroke_counts
# Out:
# stroke                0         1
# heart_disease
# 0              0.958213  0.041787
# 1              0.829710  0.170290

# %%
# Plot a bar diagram
stroke_counts.plot(kind='bar', stacked=True, color =["#3498db", "#e74c3c"])
plt.title("Proportion of Stroke Cases by heart_disease")
plt.xlabel("Heart disease (0 = No, 1 = Yes)")
plt.ylabel("Proportion")
plt.legend(["No Stroke", "Stroke"], title="Stroke Status")
plt.show()

# %% [markdown]
# ### It is clear that the risk of stroke is higher in the people with heart-disease.

# %% [markdown]
# ## The relationship between age and average of glucose level

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp; There are only two continuous variables with full data. I try to se how the relationship looks like, just for fun.

# %%
# Numerical vs. Numerical - age vs. average of glucose level
plt.figure(figsize=(8, 5))
sns.scatterplot(x='age', y='avg_glucose_level', data=df3, alpha=0.7)
plt.title('Age vs. Average of glucose level')
plt.show()

# %% [markdown]
# ### &nbsp;&nbsp;&nbsp;&nbsp; From the chart, it can be seen that the number of people with significantly high blood sugar levels increases noticeably starting from around the age of 40.
